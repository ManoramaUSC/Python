# %%
import math
print("----------1.1------------")
name = input("Enter your name: ")
print("Hello {}".format(name))
# Out:
# ----------1.1------------
# Enter your name: Manorama Patil
# Hello Manorama Patil

# %% [markdown]
# 2)

# %%
d1,d2 = map(int, input("enter two integers: ").split())
print("total = {}".format(d1+d2))
# Out:
# enter two integers: 11 12
# total = 23

# %% [markdown]
# 3)

# %%
cel = int(input("enter temperature in celsius: "))
print("temperature in Fahrenheit = {}".format(((9*cel)/5) + 32))
# Out:
# enter temperature in celsius: 23
# temperature in Fahrenheit = 73.4

# %% [markdown]
# 4)

# %%
p,r,t = map(int, input("enter principle, rate and time: ").split())
print("Simple interest = {}".format((p*r*t)/100))
# Out:
# enter principle, rate and time: 1000 10 3
# Simple interest = 300.0

# %% [markdown]
# 5)

# %%
seconds = int(input("enter seconds: "))
mins, sec = divmod(seconds, 60)
hour, mins = divmod(mins, 60)
print("Hours: {}".format(hour))
print("Minutes: {}".format(mins))
print("Seconds: {}".format(sec))
# Out:
# enter seconds: 1000
# Hours: 0
# Minutes: 16
# Seconds: 40

# %% [markdown]
# 6)

# %%
a = int(input("enter val of a: "))
b = int(input("enter val of b: "))
a,b = b,a
print("a = {} b = {}".format(a,b))
# Out:
# enter val of a: 7
# enter val of b: 8
# a = 8 b = 7

# %% [markdown]
# 7)

# %%
l = int(input("enter val of a: "))
m = int(input("enter val of b: "))
l,m = m,l
print("a = {} b = {}".format(l,m))
# Out:
# enter val of a: 20
# enter val of b: 30
# a = 30 b = 20

# %% [markdown]
# 8)

# %%
rad = int(input("enter radius: "))
Pi = 3.14
print("Area = {}".format(Pi*(rad*rad)))
print("Circumference = {}".format(2*Pi*rad))
# Out:
# enter radius: 20
# Area = 1256.0
# Circumference = 125.60000000000001

# %% [markdown]
# 9)

# %%
le,wi = map(int,input("enter length and width: ").split())
print("Area = {}".format(le*wi))
print("Circumference = {}".format(2*(le+wi)))
# Out:
# enter length and width: 20 30
# Area = 600
# Circumference = 100

# %% [markdown]
# 10)

# %%
s1,s2,s3 = map(int,input("enter length of triangle's sides: ").split())
s = (s1+s2+s3)/2
area = (s*(s-s1)*(s-s2)*(s-s3)) ** 0.5
print("Area = {}".format(area))
# Out:
# enter length of triangle's sides: 20 30 40
# Area = 290.4737509655563

# %% [markdown]
# 11)

# %%
p1,r1,t1 = map(float, input("enter principle, rate and time: ").split())
amt = p1 * (pow((1 + r1 / 100), t1))
CI = amt - p1
print("Compound interest is", CI)
# Out:
# enter principle, rate and time: 10000 10 3
# Compound interest is 3310.0000000000036
