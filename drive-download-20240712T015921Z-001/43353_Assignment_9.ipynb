# %% [markdown]
# Manorama Patil
#
# 43353
#
# BE-11
#
# Information Technology

# %%
#Importing the libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
dataset = pd.read_csv('Churn_Modelling.csv')

# %%
X = dataset.iloc[:, 3:13].values

# %%
y = dataset.iloc[:, 13].values

# %%
print(X)
# Out:
# [[619 'France' 'Female' ... 1 1 101348.88]
#  [608 'Spain' 'Female' ... 0 1 112542.58]
#  [502 'France' 'Female' ... 1 0 113931.57]
#  ...
#  [709 'France' 'Female' ... 0 1 42085.58]
#  [772 'Germany' 'Male' ... 1 0 92888.52]
#  [792 'France' 'Female' ... 1 0 38190.78]]

# %%
print(y)
# Out:
# [1 0 1 ... 1 1 0]

# %%
#Encoding
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
labelencoder_X_1 = LabelEncoder()
X[:, 1] = labelencoder_X_1.fit_transform(X[:, 1])
labelencoder_X_2 = LabelEncoder()
X[:, 2] = labelencoder_X_2.fit_transform(X[:, 2])

#Creating Dummy variables
##X = onehotencoder.fit_transform(X).toarray()
#X = X[:, 1:]

# %%
#Splitting the dataset
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)

# %%
#Feature Scaling
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %% [markdown]
# #### ANN

# %%
#Importing the Keras libraries and packages
import keras
from keras.models import Sequential#For building the Neural Network layer by layer
from keras.layers import Dense#To randomly initialize the weights to small numbers close to 0(But not 0)

# %%
classifier = Sequential()

# %%
#Adding the input layer and the first hidden layer
classifier.add(Dense(units = 6, activation = 'relu'))

# %%
#Adding the second hidden layer
classifier.add(Dense(units = 6, activation = 'relu'))

# %%
#Adding the output layer
classifier.add(Dense(units = 1, activation = 'sigmoid'))

# %%
#Compiling the ANN
classifier.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])

# %%
#Fitting the ANN to the Training set
classifier.fit(X_train, y_train, batch_size = 10, epochs = 100)
# Out:
# Epoch 1/100
# 800/800 [==============================] - 1s 806us/step - loss: 0.5118 - accuracy: 0.7832
# Epoch 2/100
# 800/800 [==============================] - 1s 771us/step - loss: 0.4382 - accuracy: 0.8124
# Epoch 3/100
# 800/800 [==============================] - 1s 818us/step - loss: 0.4212 - accuracy: 0.8138
# Epoch 4/100
# 800/800 [==============================] - 1s 776us/step - loss: 0.4099 - accuracy: 0.8139
# Epoch 5/100
# 800/800 [==============================] - 1s 823us/step - loss: 0.4029 - accuracy: 0.8186
# Epoch 6/100
# 800/800 [==============================] - 1s 782us/step - loss: 0.3971 - accuracy: 0.8188
# Epoch 7/100
# 800/800 [==============================] - 1s 849us/step - loss: 0.3932 - accuracy: 0.8210
# Epoch 8/100
# 800/800 [==============================] - 1s 836us/step - loss: 0.3897 - accuracy: 0.8210
# Epoch 9/100
# 800/800 [==============================] - 1s 820us/step - loss: 0.3878 - accuracy: 0.8217
# Epoch 10/100
# 800/800 [==============================] - 1s 844us/step - loss: 0.3841 - accuracy: 0.8231
# Epoch 11/100
# 800/800 [==============================] - 1s 821us/step - loss: 0.3823 - accuracy: 0.8219
# Epoch 12/100
# 800/800 [==============================] - 1s 806us/step - loss: 0.3797 - accuracy: 0.8236
# Epoch 13/100
# 800/800 [==============================] - 1s 803us/step - loss: 0.3771 - accuracy: 0.8292
# Epoch 14/100
# 800/800 [==============================] - 1s 795us/step - loss: 0.3746 - accuracy: 0.8430
# Epoch 15/100
# 800/800 [==============================] - 1s 788us/step - loss: 0.3718 - accuracy: 0.8480
# Epoch 16/100
# 800/800 [==============================] - 1s 798us/step - loss: 0.3695 - accuracy: 0.8493
# Epoch 17/100
# 800/800 [==============================] - 1s 817us/step - loss: 0.3671 - accuracy: 0.8539
# Epoch 18/100
# 800/800 [==============================] - 1s 811us/step - loss: 0.3650 - accuracy: 0.8531
# Epoch 19/100
# 800/800 [==============================] - 1s 812us/step - loss: 0.3629 - accuracy: 0.8549
# Epoch 20/100
# 800/800 [==============================] - 1s 954us/step - loss: 0.3606 - accuracy: 0.8561
# Epoch 21/100
# 800/800 [==============================] - ETA: 0s - loss: 0.3571 - accuracy: 0.85 - 1s 791us/step - loss: 0.3584 - accuracy: 0.8574
# Epoch 22/100
# 800/800 [==============================] - 1s 785us/step - loss: 0.3572 - accuracy: 0.8572
# Epoch 23/100
# 800/800 [==============================] - 1s 786us/step - loss: 0.3561 - accuracy: 0.8565
# Epoch 24/100
# 800/800 [==============================] - 1s 786us/step - loss: 0.3550 - accuracy: 0.8577
# Epoch 25/100
# 800/800 [==============================] - 1s 824us/step - loss: 0.3536 - accuracy: 0.8583
# Epoch 26/100
# 800/800 [==============================] - 1s 791us/step - loss: 0.3526 - accuracy: 0.8568
# Epoch 27/100
# 800/800 [==============================] - 1s 793us/step - loss: 0.3512 - accuracy: 0.8577
# Epoch 28/100
# 800/800 [==============================] - 1s 794us/step - loss: 0.3501 - accuracy: 0.8583
# Epoch 29/100
# 800/800 [==============================] - 1s 1ms/step - loss: 0.3491 - accuracy: 0.8590
# Epoch 30/100
# 800/800 [==============================] - 1s 867us/step - loss: 0.3475 - accuracy: 0.8590
# Epoch 31/100
# 800/800 [==============================] - 1s 989us/step - loss: 0.3468 - accuracy: 0.8606
# Epoch 32/100
# 800/800 [==============================] - 1s 916us/step - loss: 0.3456 - accuracy: 0.8629
# Epoch 33/100
# 800/800 [==============================] - 1s 817us/step - loss: 0.3448 - accuracy: 0.8594
# Epoch 34/100
# 800/800 [==============================] - 1s 806us/step - loss: 0.3439 - accuracy: 0.8606
# Epoch 35/100
# 800/800 [==============================] - 1s 798us/step - loss: 0.3434 - accuracy: 0.8581
# Epoch 36/100
# 800/800 [==============================] - 1s 820us/step - loss: 0.3427 - accuracy: 0.8610
# Epoch 37/100
# 800/800 [==============================] - 1s 789us/step - loss: 0.3425 - accuracy: 0.8611
# Epoch 38/100
# 800/800 [==============================] - 1s 987us/step - loss: 0.3417 - accuracy: 0.8610
# Epoch 39/100
# 800/800 [==============================] - 1s 784us/step - loss: 0.3413 - accuracy: 0.8618
# Epoch 40/100
# 800/800 [==============================] - 1s 1ms/step - loss: 0.3409 - accuracy: 0.8610
# Epoch 41/100
# 800/800 [==============================] - 1s 837us/step - loss: 0.3408 - accuracy: 0.8621
# Epoch 42/100
# 800/800 [==============================] - 1s 883us/step - loss: 0.3402 - accuracy: 0.8618
# Epoch 43/100
# 800/800 [==============================] - 1s 822us/step - loss: 0.3401 - accuracy: 0.8626
# Epoch 44/100
# 800/800 [==============================] - 1s 830us/step - loss: 0.3392 - accuracy: 0.8626
# Epoch 45/100
# 800/800 [==============================] - 1s 780us/step - loss: 0.3392 - accuracy: 0.8615
# Epoch 46/100
# 800/800 [==============================] - 1s 801us/step - loss: 0.3392 - accuracy: 0.8618
# Epoch 47/100
# 800/800 [==============================] - 1s 781us/step - loss: 0.3389 - accuracy: 0.8621
# Epoch 48/100
# 800/800 [==============================] - 1s 806us/step - loss: 0.3389 - accuracy: 0.86140s - loss: 0.3
# Epoch 49/100
# 800/800 [==============================] - 1s 832us/step - loss: 0.3378 - accuracy: 0.8626
# Epoch 50/100
# 800/800 [==============================] - 1s 786us/step - loss: 0.3385 - accuracy: 0.8655
# Epoch 51/100
# 800/800 [==============================] - 1s 805us/step - loss: 0.3377 - accuracy: 0.8641
# Epoch 52/100
# 800/800 [==============================] - 1s 846us/step - loss: 0.3378 - accuracy: 0.86310s - loss: 0.334
# Epoch 53/100
# 800/800 [==============================] - 1s 812us/step - loss: 0.3384 - accuracy: 0.8626
# Epoch 54/100
# 800/800 [==============================] - 1s 787us/step - loss: 0.3375 - accuracy: 0.8655
# Epoch 55/100
# 800/800 [==============================] - 1s 913us/step - loss: 0.3374 - accuracy: 0.8633
# Epoch 56/100
# 800/800 [==============================] - 1s 872us/step - loss: 0.3378 - accuracy: 0.8635
# Epoch 57/100
# 800/800 [==============================] - 1s 799us/step - loss: 0.3370 - accuracy: 0.8627
# Epoch 58/100
# 800/800 [==============================] - 1s 878us/step - loss: 0.3371 - accuracy: 0.8630
# Epoch 59/100
# 800/800 [==============================] - 1s 892us/step - loss: 0.3365 - accuracy: 0.8649
# Epoch 60/100
# 800/800 [==============================] - 1s 921us/step - loss: 0.3365 - accuracy: 0.8627
# Epoch 61/100
# 800/800 [==============================] - 1s 781us/step - loss: 0.3366 - accuracy: 0.8639
# Epoch 62/100
# 800/800 [==============================] - 1s 792us/step - loss: 0.3354 - accuracy: 0.8654
# Epoch 63/100
# 800/800 [==============================] - 1s 938us/step - loss: 0.3354 - accuracy: 0.8665
# Epoch 64/100
# 800/800 [==============================] - 1s 833us/step - loss: 0.3357 - accuracy: 0.8639
# Epoch 65/100
# 800/800 [==============================] - 1s 823us/step - loss: 0.3364 - accuracy: 0.8630
# Epoch 66/100
# 800/800 [==============================] - 1s 807us/step - loss: 0.3354 - accuracy: 0.8670
# Epoch 67/100
# 800/800 [==============================] - 1s 788us/step - loss: 0.3353 - accuracy: 0.8615
# Epoch 68/100
# 800/800 [==============================] - 1s 787us/step - loss: 0.3355 - accuracy: 0.8651
# Epoch 69/100
# 800/800 [==============================] - 1s 786us/step - loss: 0.3350 - accuracy: 0.8645
# Epoch 70/100
# 800/800 [==============================] - 1s 806us/step - loss: 0.3355 - accuracy: 0.8626
# Epoch 71/100
# 800/800 [==============================] - 1s 813us/step - loss: 0.3353 - accuracy: 0.8652
# Epoch 72/100
# 800/800 [==============================] - 1s 838us/step - loss: 0.3355 - accuracy: 0.86240s - loss: 0
# Epoch 73/100
# 800/800 [==============================] - 1s 776us/step - loss: 0.3349 - accuracy: 0.8637
# Epoch 74/100
# 800/800 [==============================] - 1s 781us/step - loss: 0.3350 - accuracy: 0.8646
# Epoch 75/100
# 800/800 [==============================] - 1s 848us/step - loss: 0.3347 - accuracy: 0.8637
# Epoch 76/100
# 800/800 [==============================] - 1s 844us/step - loss: 0.3351 - accuracy: 0.8637
# Epoch 77/100
# 800/800 [==============================] - 1s 848us/step - loss: 0.3350 - accuracy: 0.8648
# Epoch 78/100
# 800/800 [==============================] - 1s 810us/step - loss: 0.3356 - accuracy: 0.86250s - loss: 0.3485 - ac
# Epoch 79/100
# 800/800 [==============================] - 1s 910us/step - loss: 0.3347 - accuracy: 0.8644
# Epoch 80/100
# 800/800 [==============================] - 1s 865us/step - loss: 0.3350 - accuracy: 0.8635
# Epoch 81/100
# 800/800 [==============================] - 1s 783us/step - loss: 0.3346 - accuracy: 0.8639
# Epoch 82/100
# 800/800 [==============================] - 1s 819us/step - loss: 0.3347 - accuracy: 0.8633
# Epoch 83/100
# 800/800 [==============================] - 1s 794us/step - loss: 0.3339 - accuracy: 0.8643
# Epoch 84/100
# 800/800 [==============================] - 1s 792us/step - loss: 0.3346 - accuracy: 0.8630
# Epoch 85/100
# 800/800 [==============================] - 1s 780us/step - loss: 0.3347 - accuracy: 0.8639
# Epoch 86/100
# 800/800 [==============================] - 1s 799us/step - loss: 0.3342 - accuracy: 0.8631
# Epoch 87/100
# 800/800 [==============================] - 1s 826us/step - loss: 0.3346 - accuracy: 0.8644
# Epoch 88/100
# 800/800 [==============================] - 1s 786us/step - loss: 0.3346 - accuracy: 0.8658
# Epoch 89/100
# 800/800 [==============================] - 1s 789us/step - loss: 0.3336 - accuracy: 0.8650
# Epoch 90/100
# 800/800 [==============================] - 1s 775us/step - loss: 0.3338 - accuracy: 0.8640
# Epoch 91/100
# 800/800 [==============================] - 1s 830us/step - loss: 0.3340 - accuracy: 0.8656
# Epoch 92/100
# 800/800 [==============================] - 1s 813us/step - loss: 0.3342 - accuracy: 0.8633
# Epoch 93/100
# 800/800 [==============================] - 1s 778us/step - loss: 0.3348 - accuracy: 0.8620
# Epoch 94/100
# 800/800 [==============================] - 1s 806us/step - loss: 0.3338 - accuracy: 0.8641
# Epoch 95/100
# 800/800 [==============================] - 1s 844us/step - loss: 0.3342 - accuracy: 0.8631
# Epoch 96/100
# 800/800 [==============================] - 1s 783us/step - loss: 0.3340 - accuracy: 0.8641
# Epoch 97/100
# 800/800 [==============================] - 1s 816us/step - loss: 0.3337 - accuracy: 0.8639
# Epoch 98/100
# 800/800 [==============================] - 1s 802us/step - loss: 0.3329 - accuracy: 0.8643
# Epoch 99/100
# 800/800 [==============================] - 1s 782us/step - loss: 0.3336 - accuracy: 0.8626
# Epoch 100/100
# 800/800 [==============================] - 1s 777us/step - loss: 0.3336 - accuracy: 0.8630

# %%
#Predicting the Test set results
y_pred = classifier.predict(X_test)
y_pred = (y_pred > 0.5)
print(y_pred)
# Out:
# [[False]
#  [False]
#  [False]
#  ...
#  [False]
#  [False]
#  [False]]

# %%
# Making the Confusion Matrix
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_pred)
print(cm)
accuracy=(1550+175)/2000
print(accuracy)
# Out:
# [[1480  115]
#  [ 179  226]]
# 0.8625
